# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read csv
trates = pd.read_csv('rates.csv')

# %%
#print data
print(trates.head())
# Out:
#          Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0  08/04/2023  5.54  5.51  5.54  5.52  5.50  5.33  4.78  4.45  4.15  4.10
# 1  08/03/2023  5.54  5.52  5.54  5.53  5.52  5.37  4.90  4.58  4.30  4.26
# 2  08/02/2023  5.48  5.53  5.53  5.54  5.52  5.36  4.88  4.54  4.24  4.17
# 3  08/01/2023  5.49  5.54  5.54  5.57  5.54  5.38  4.92  4.57  4.24  4.15
# 4  07/31/2023  5.48  5.54  5.55  5.56  5.53  5.37  4.88  4.51  4.18  4.08
#
#    10 Yr  20 Yr  30 Yr
# 0   4.05   4.36   4.21
# 1   4.20   4.49   4.32
# 2   4.08   4.35   4.17
# 3   4.05   4.30   4.11
# 4   3.97   4.22   4.02

# %%
#plot 10y data
ax = sns.lineplot(data = trates, x = "Date", y = "10 Yr")

# %%
#check data
trates.dtypes
# Out:
# Date      object
# 1 Mo     float64
# 2 Mo     float64
# 3 Mo     float64
# 4 Mo     float64
# 6 Mo     float64
# 1 Yr     float64
# 2 Yr     float64
# 3 Yr     float64
# 5 Yr     float64
# 7 Yr     float64
# 10 Yr    float64
# 20 Yr    float64
# 30 Yr    float64
# dtype: object

# %%
#set index to Date
trates = trates.set_index('Date')

# %%
print(trates.head())
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 08/04/2023  5.54  5.51  5.54  5.52  5.50  5.33  4.78  4.45  4.15  4.10   4.05
# 08/03/2023  5.54  5.52  5.54  5.53  5.52  5.37  4.90  4.58  4.30  4.26   4.20
# 08/02/2023  5.48  5.53  5.53  5.54  5.52  5.36  4.88  4.54  4.24  4.17   4.08
# 08/01/2023  5.49  5.54  5.54  5.57  5.54  5.38  4.92  4.57  4.24  4.15   4.05
# 07/31/2023  5.48  5.54  5.55  5.56  5.53  5.37  4.88  4.51  4.18  4.08   3.97
#
#             20 Yr  30 Yr
# Date
# 08/04/2023   4.36   4.21
# 08/03/2023   4.49   4.32
# 08/02/2023   4.35   4.17
# 08/01/2023   4.30   4.11
# 07/31/2023   4.22   4.02

# %%
#plot all maturities
trates.plot(y = ['1 Mo', '2 Mo', '3 Mo', '4 Mo', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr'])
# Out:
# <Axes: xlabel='Date'>

# %%
#trates = trates.set_index('Date', inplace = True)

# %%
#print(newrates)
#trates['Date'] = pd.to_datetime(trates['Date'], infer_datetime_format=True)
#trates.index = pd.to_datetime(trates.index)

# %%
trates
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 08/04/2023  5.54  5.51  5.54  5.52  5.50  5.33  4.78  4.45  4.15  4.10   4.05
# 08/03/2023  5.54  5.52  5.54  5.53  5.52  5.37  4.90  4.58  4.30  4.26   4.20
# 08/02/2023  5.48  5.53  5.53  5.54  5.52  5.36  4.88  4.54  4.24  4.17   4.08
# 08/01/2023  5.49  5.54  5.54  5.57  5.54  5.38  4.92  4.57  4.24  4.15   4.05
# 07/31/2023  5.48  5.54  5.55  5.56  5.53  5.37  4.88  4.51  4.18  4.08   3.97
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 01/09/2023  4.37  4.58  4.70  4.74  4.83  4.69  4.19  3.93  3.66  3.60   3.53
# 01/06/2023  4.32  4.55  4.67  4.74  4.79  4.71  4.24  3.96  3.69  3.63   3.55
# 01/05/2023  4.30  4.55  4.66  4.75  4.81  4.78  4.45  4.18  3.90  3.82   3.71
# 01/04/2023  4.20  4.42  4.55  4.69  4.77  4.71  4.36  4.11  3.85  3.79   3.69
# 01/03/2023  4.17  4.42  4.53  4.70  4.77  4.72  4.40  4.18  3.94  3.89   3.79
#
#             20 Yr  30 Yr
# ...

# %%
#sort index chronoligically
trates = trates.sort_index()

# %%
trates
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 01/03/2023  4.17  4.42  4.53  4.70  4.77  4.72  4.40  4.18  3.94  3.89   3.79
# 01/04/2023  4.20  4.42  4.55  4.69  4.77  4.71  4.36  4.11  3.85  3.79   3.69
# 01/05/2023  4.30  4.55  4.66  4.75  4.81  4.78  4.45  4.18  3.90  3.82   3.71
# 01/06/2023  4.32  4.55  4.67  4.74  4.79  4.71  4.24  3.96  3.69  3.63   3.55
# 01/09/2023  4.37  4.58  4.70  4.74  4.83  4.69  4.19  3.93  3.66  3.60   3.53
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 07/31/2023  5.48  5.54  5.55  5.56  5.53  5.37  4.88  4.51  4.18  4.08   3.97
# 08/01/2023  5.49  5.54  5.54  5.57  5.54  5.38  4.92  4.57  4.24  4.15   4.05
# 08/02/2023  5.48  5.53  5.53  5.54  5.52  5.36  4.88  4.54  4.24  4.17   4.08
# 08/03/2023  5.54  5.52  5.54  5.53  5.52  5.37  4.90  4.58  4.30  4.26   4.20
# 08/04/2023  5.54  5.51  5.54  5.52  5.50  5.33  4.78  4.45  4.15  4.10   4.05
#
#             20 Yr  30 Yr
# ...

# %%
#trates.plot(y = ['1 Mo', '2 Mo', '3 Mo', '4 Mo', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr'])

# %%
#plot all maturities
trates.plot(y = ['1 Mo', '2 Mo', '3 Mo', '4 Mo', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr'])
# Out:
# <Axes: xlabel='Date'>

# %%
#make plot larger for clarity and select colour scheme
sns.set(rc = {'figure.figsize':(15,8)})
sns.color_palette("tab10")

# %%
#set colour scheme and plot only major maturities for clarity
sns.color_palette("tab10")
trates.plot(y = ['3 Mo', '1 Yr', '2 Yr', '5 Yr', '10 Yr', '20 Yr', '30 Yr'])
# Out:
# <Axes: xlabel='Date'>

# %%
#ax4 = sns.lineplot(data = trates, x ='Date', y = ['3 Mo', '1 Yr', '2 Yr', '5 Yr', '10 Yr', '20 Yr', '30 Yr'])
